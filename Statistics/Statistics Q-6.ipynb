# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x = pd.read_csv("data.csv")


#Creating a Function.
def normal_dist(x , mean , sd):
    prob_density = (np.pi*sd) * np.exp(-0.5*((x-mean)/sd)**2)
    return prob_density

#Calculate mean and Standard deviation.
mean = np.mean(x)
sd = np.std(x)

#Apply function to the data.
pdf = normal_dist(x,mean,sd)

#Plotting the Results
plt.plot(x,pdf , color = 'red')
plt.xlabel('Data points')
plt.ylabel('Probability Density')
# Out:
# D:\ineuron\lib\site-packages\numpy\core\fromnumeric.py:3438: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File D:\ineuron\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File D:\ineuron\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\ineuron\lib\site-packages\pandas\_libs\index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), None)' is an invalid key
#
# ...

# %%
x = pd.read_csv("data.csv")

# %%
x.columns
# Out:
# Index(['Patient ID', ' Blood Pressure Before (mmHg)',
#        ' Blood Pressure After (mmHg)'],
#       dtype='object')

# %%
x1 = x[' Blood Pressure Before (mmHg)']

# %%
x2 = x[' Blood Pressure After (mmHg)']

# %%
from scipy import stats

# %%
x1 = np.linspace(-10, 10, 100)
#
plt.figure(figsize=(7.5,7.5))
#
# Normal distribution with mean 0 and std as 1
#
plt.plot(x1, stats.norm(0, 1).pdf(x1))
#
# Normal distribution with mean 1 and std as 0.75
#
plt.plot(x1, stats.norm(1, 0.75).pdf(x1))
#
# Normal distribution with mean 2 and std as 1.5
#
plt.plot(x1, stats.norm(2, 1.5).pdf(x1))
plt.xlim(-10, 10)
plt.title('Normal Distribution', fontsize='15')
plt.xlabel('Values of blood pressure before', fontsize='15')
plt.ylabel('Probability', fontsize='15')
plt.show()

# %%
x2 = np.linspace(-10, 10, 100)
#
plt.figure(figsize=(7.5,7.5))
#
# Normal distribution with mean 0 and std as 1
#
plt.plot(x2, stats.norm(0, 1).pdf(x2))
#
# Normal distribution with mean 1 and std as 0.75
#
plt.plot(x2, stats.norm(1, 0.75).pdf(x2))
#
# Normal distribution with mean 2 and std as 1.5
#
plt.plot(x2, stats.norm(2, 1.5).pdf(x2))
plt.xlim(-10, 10)
plt.title('Normal Distribution', fontsize='15')
plt.xlabel('Values of blood pressure after', fontsize='15')
plt.ylabel('Probability', fontsize='15')
plt.show()

# %%
x['BP_diff'] = x[' Blood Pressure Before (mmHg)'] - x[' Blood Pressure After (mmHg)']

# %%
x
# Out:
#     Patient ID   Blood Pressure Before (mmHg)   Blood Pressure After (mmHg)  \
# 0            1                            130                           120
# 1            2                            142                           135
# 2            3                            120                           118
# 3            4                            135                           127
# 4            5                            148                           140
# ..         ...                            ...                           ...
# 95          96                            136                           129
# 96          97                            143                           137
# 97          98                            127                           123
# 98          99                            139                           135
# 99         100                            135                           130
#
#     BP_diff
# 0        10
# 1         7
# 2         2
# ...

# %%
x3 = x['BP_diff']

# %%
x3 = np.linspace(-10, 10, 100)
#
plt.figure(figsize=(7.5,7.5))
#
# Normal distribution with mean 0 and std as 1
#
plt.plot(x3, stats.norm(0, 1).pdf(x3))
#
# Normal distribution with mean 1 and std as 0.75
#
plt.plot(x3, stats.norm(1, 0.75).pdf(x3))
#
# Normal distribution with mean 2 and std as 1.5
#
plt.plot(x3, stats.norm(2, 1.5).pdf(x3))
plt.xlim(-10, 10)
plt.title('Normal Distribution', fontsize='15')
plt.xlabel('Normal Distribution of change in BP', fontsize='15')
plt.ylabel('Probability', fontsize='15')
plt.show()

# %% [markdown]
# The above graph depicts the variation of blood pressure and also its probability factor.
