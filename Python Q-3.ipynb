# %%
import json
import pandas as pd
from pandas import json_normalize

# %%
# Open the pokedex.json downloaded after uploaded into jupyter notebook 
with open("pokedex.json") as file:
    # Load its content and make a new dictionary
    data = json.load(file)

    #Order the data by loading into a data frame df_json
df_json = pd.DataFrame(data)
df_json
# Out:
#                                                pokemon
# 0    {'id': 1, 'num': '001', 'name': 'Bulbasaur', '...
# 1    {'id': 2, 'num': '002', 'name': 'Ivysaur', 'im...
# 2    {'id': 3, 'num': '003', 'name': 'Venusaur', 'i...
# 3    {'id': 4, 'num': '004', 'name': 'Charmander', ...
# 4    {'id': 5, 'num': '005', 'name': 'Charmeleon', ...
# ..                                                 ...
# 146  {'id': 147, 'num': '147', 'name': 'Dratini', '...
# 147  {'id': 148, 'num': '148', 'name': 'Dragonair',...
# 148  {'id': 149, 'num': '149', 'name': 'Dragonite',...
# 149  {'id': 150, 'num': '150', 'name': 'Mewtwo', 'i...
# 150  {'id': 151, 'num': '151', 'name': 'Mew', 'img'...
#
# [151 rows x 1 columns]

# %% [raw]
# Above the json data is converted into data frame and then the nested list is flattened to extract the required data format

# %% [markdown]
# ![q3.png](attachment:q3.png)

# %%
#Then the structed and ordered data is dumped into a excel file and exported using to_excel
df_json.to_excel(r'‪Exported Pokemon Data.xlsx', index=False)

# %%
df_json.to_csv(r'Exported Pokemon Data.xls',index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 df_json.to_csv(r'EPD.xls',index=False,axis=1, inplace=True)
#
# TypeError: to_csv() got an unexpected keyword argument 'axis'

# %% [markdown]
# ![image.png](attachment:image.png)
