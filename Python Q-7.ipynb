# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
from statsmodels.graphics.mosaicplot import mosaic
import seaborn as sns

# %%
#Open the pokedex.json downloaded after uploaded into jupyter notebook 
with open(r'C:\Users\Lenovo\Downloads\q4.json','r',encoding='utf-8') as file:
    # Load its content and make a new dictionary
    data = json.load(file)

    #Order the data by loading into a data frame df_json
df_json = pd.DataFrame(data)
df_json
# Out:
#           name     id nametype               recclass    mass  fall  \
# 0       Aachen      1    Valid                     L5      21  Fell
# 1       Aarhus      2    Valid                     H6     720  Fell
# 2         Abee      6    Valid                    EH4  107000  Fell
# 3     Acapulco     10    Valid            Acapulcoite    1914  Fell
# 4      Achiras    370    Valid                     L6     780  Fell
# ..         ...    ...      ...                    ...     ...   ...
# 995   Tirupati  24009    Valid                     H6     230  Fell
# 996    Tissint  54823    Valid  Martian (shergottite)    7000  Fell
# 997      Tjabe  24011    Valid                     H6   20000  Fell
# 998   Tjerebon  24012    Valid                     L5   16500  Fell
# 999  Tomakovka  24019    Valid                    LL6     600  Fell
#
#                         year      reclat      reclong  \
# 0    1880-01-01T00:00:00.000   50.775000     6.083330
# ...

# %% [markdown]
# **Query-1 : Get all the Earth meteorites that fell before the year 2000**

# %%
df1 = df_json[["name","fall","year"]]

# %%
filtered_df = df1.loc[(df1['year'] < '2000-01-01T00:00:00.000')
                     & (df1['year'] < '2000-01-01T00:00:00.000')]
# Display
filtered_df[["name","fall","year"]]
# Out:
#           name  fall                     year
# 0       Aachen  Fell  1880-01-01T00:00:00.000
# 1       Aarhus  Fell  1951-01-01T00:00:00.000
# 2         Abee  Fell  1952-01-01T00:00:00.000
# 3     Acapulco  Fell  1976-01-01T00:00:00.000
# 4      Achiras  Fell  1902-01-01T00:00:00.000
# ..         ...   ...                      ...
# 994   Timochin  Fell  1807-01-01T00:00:00.000
# 995   Tirupati  Fell  1934-01-01T00:00:00.000
# 997      Tjabe  Fell  1869-01-01T00:00:00.000
# 998   Tjerebon  Fell  1922-01-01T00:00:00.000
# 999  Tomakovka  Fell  1905-01-01T00:00:00.000
#
# [929 rows x 3 columns]

# %%
# Create figure and plot space
fig, ax = plt.subplots(figsize=(20, 40))

# Add x-axis and y-axis
ax.plot(filtered_df['name'],
        filtered_df['year'],
        color='purple')

# Set title and labels for axes
ax.set(xlabel="name",
       ylabel="year",
       title="Earth Meteoerites that fell into the year 2000")

plt.show()

# %% [markdown]
# **Query-2 : Get all the earth meteorites co-ordinates who fell before the year 1970**

# %%
filtered_df1 = df1.loc[(df1['year'] < '1970-01-01T00:00:00.000')
                     & (df1['year'] < '1970-01-01T00:00:00.000')]
# Display
filtered_df1[["name","fall","year"]]
# Out:
#           name  fall                     year
# 0       Aachen  Fell  1880-01-01T00:00:00.000
# 1       Aarhus  Fell  1951-01-01T00:00:00.000
# 2         Abee  Fell  1952-01-01T00:00:00.000
# 4      Achiras  Fell  1902-01-01T00:00:00.000
# 5     Adhi Kot  Fell  1919-01-01T00:00:00.000
# ..         ...   ...                      ...
# 994   Timochin  Fell  1807-01-01T00:00:00.000
# 995   Tirupati  Fell  1934-01-01T00:00:00.000
# 997      Tjabe  Fell  1869-01-01T00:00:00.000
# 998   Tjerebon  Fell  1922-01-01T00:00:00.000
# 999  Tomakovka  Fell  1905-01-01T00:00:00.000
#
# [780 rows x 3 columns]

# %%
sns.catplot(data=filtered_df1, x="year", y="name",height=6, aspect=4)

# %% [markdown]
# **Query-3 : Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more
# than 10000kg**

# %%
df2= df_json[["name","mass"]]

# %%
df2
# Out:
#           name    mass
# 0       Aachen      21
# 1       Aarhus     720
# 2         Abee  107000
# 3     Acapulco    1914
# 4      Achiras     780
# ..         ...     ...
# 995   Tirupati     230
# 996    Tissint    7000
# 997      Tjabe   20000
# 998   Tjerebon   16500
# 999  Tomakovka     600
#
# [1000 rows x 2 columns]

# %%
df2['mass'].dtype
# Out:
# dtype('O')

# %%
df2
# Out:
#           name    mass
# 0       Aachen      21
# 1       Aarhus     720
# 2         Abee  107000
# 3     Acapulco    1914
# 4      Achiras     780
# ..         ...     ...
# 995   Tirupati     230
# 996    Tissint    7000
# 997      Tjabe   20000
# 998   Tjerebon   16500
# 999  Tomakovka     600
#
# [1000 rows x 2 columns]

# %%
df2['equal_or_lower_than_10000?'] = df2['mass'].apply(lambda x: 'True' if int(x) >= 10000 else 'False')

print(df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 df2['equal_or_lower_than_10000?'] = df2['mass'].apply(lambda x: 'True' if int(x) >= 10000 else 'False')
#       3 print(df2)
#
# File D:\ineuron\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File D:\ineuron\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
# ...

# %%
df3 = df2.dropna(subset=['mass'])

df2['mass'] = df2['mass'].astype(Int32)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [42], in <cell line: 3>()
#       1 df3 = df2.dropna(subset=['mass'])
# ----> 3 df2['mass'] = df2['mass'].astype(Int32)
#
# NameError: name 'Int32' is not defined
