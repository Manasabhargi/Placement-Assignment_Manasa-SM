# %%
import requests
import json
response_API = requests.get('http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes')
#print(response_API.status_code)
import pandas as pd
from tabulate import tabulate

# %%
data = response_API.text

# %%
df = json.loads(data)
df
# Out:
# {'id': 1371,
#  'url': 'https://www.tvmaze.com/shows/1371/westworld',
#  'name': 'Westworld',
#  'type': 'Scripted',
#  'language': 'English',
#  'genres': ['Drama', 'Science-Fiction', 'Western'],
#  'status': 'Ended',
#  'runtime': 60,
#  'averageRuntime': 63,
#  'premiered': '2016-10-02',
#  'ended': '2022-08-14',
#  'officialSite': 'http://www.hbo.com/westworld',
#  'schedule': {'time': '21:00', 'days': ['Sunday']},
#  'rating': {'average': 8.2},
#  'weight': 99,
#  'network': {'id': 8,
#   'name': 'HBO',
#   'country': {'name': 'United States',
#    'code': 'US',
#    'timezone': 'America/New_York'},
#   'officialSite': 'https://www.hbo.com/'},
#  'webChannel': None,
#  'dvdCountry': None,
#  'externals': {'tvrage': 37537, 'thetvdb': 296762, 'imdb': 'tt0475784'},
#  'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/445/1113927.jpg',
#   'original': 'https://static.tvmaze.com/uploads/images/original_untouched/445/1113927.jpg'},
# ...

# %%
df1
# Out:
#      id                                          url       name      type  \
# 0  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld  Scripted
#
#   language                             genres status  runtime  averageRuntime  \
# 0  English  [Drama, Science-Fiction, Western]  Ended       60              63
#
#     premiered  ... network.country.timezone  network.officialSite  \
# 0  2016-10-02  ...         America/New_York  https://www.hbo.com/
#
#    externals.tvrage externals.thetvdb externals.imdb  \
# 0             37537            296762      tt0475784
#
#                                         image.medium  \
# 0  https://static.tvmaze.com/uploads/images/mediu...
#
#                                       image.original  \
# 0  https://static.tvmaze.com/uploads/images/origi...
#
#                     _links.self.href              _links.previousepisode.href  \
# 0  https://api.tvmaze.com/shows/1371  https://api.tvmaze.com/episodes/2326661
#
# ...

# %%
df['id']
# Out:
# 1371

# %%
df.keys()
# Out:
# dict_keys(['id', 'url', 'name', 'type', 'language', 'genres', 'status', 'runtime', 'averageRuntime', 'premiered', 'ended', 'officialSite', 'schedule', 'rating', 'weight', 'network', 'webChannel', 'dvdCountry', 'externals', 'image', 'summary', 'updated', '_links', '_embedded'])

# %%
key_list = list(df.keys())

# %%
val_list = list(df.values())

# %%
key_list[23][2]
# Out:
# 'm'

# %%
type(df)
# Out:
# dict

# %%
df1 = df["_embedded"]

# %%
df2 = df1["episodes"]

# %%
df2
# Out:
# [{'id': 869671,
#   'url': 'https://www.tvmaze.com/episodes/869671/westworld-1x01-the-original',
#   'name': 'The Original',
#   'season': 1,
#   'number': 1,
#   'type': 'regular',
#   'airdate': '2016-10-02',
#   'airtime': '21:00',
#   'airstamp': '2016-10-03T01:00:00+00:00',
#   'runtime': 68,
#   'rating': {'average': 8},
#   'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_landscape/78/195475.jpg',
#    'original': 'https://static.tvmaze.com/uploads/images/original_untouched/78/195475.jpg'},
#   'summary': "<p>A woman named Dolores is a free spirit in the Old West... and unaware that she's actually an android, programmed to entertain rich guests seeking to act out their fantasies in an idealized vision of the 1880s. However, the people in charge soon realize that their androids are acting in ways that they didn't anticipate.</p>",
#   '_links': {'self': {'href': 'https://api.tvmaze.com/episodes/869671'},
# ...

# %%
df2[23]["rating"]
# Out:
# {'average': 8}

# %%
for data in df2:
    print(data)
# Out:
# {'id': 869671, 'url': 'https://www.tvmaze.com/episodes/869671/westworld-1x01-the-original', 'name': 'The Original', 'season': 1, 'number': 1, 'type': 'regular', 'airdate': '2016-10-02', 'airtime': '21:00', 'airstamp': '2016-10-03T01:00:00+00:00', 'runtime': 68, 'rating': {'average': 8}, 'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_landscape/78/195475.jpg', 'original': 'https://static.tvmaze.com/uploads/images/original_untouched/78/195475.jpg'}, 'summary': "<p>A woman named Dolores is a free spirit in the Old West... and unaware that she's actually an android, programmed to entertain rich guests seeking to act out their fantasies in an idealized vision of the 1880s. However, the people in charge soon realize that their androids are acting in ways that they didn't anticipate.</p>", '_links': {'self': {'href': 'https://api.tvmaze.com/episodes/869671'}, 'show': {'href': 'https://api.tvmaze.com/shows/1371'}}}
# ...

# %%
type(data)
# Out:
# dict

# %%
rating_access = df2[10]

# %%
rating_access
# Out:
# {'id': 1214222,
#  'url': 'https://www.tvmaze.com/episodes/1214222/westworld-2x01-journey-into-night',
#  'name': 'Journey Into Night',
#  'season': 2,
#  'number': 1,
#  'type': 'regular',
#  'airdate': '2018-04-22',
#  'airtime': '21:00',
#  'airstamp': '2018-04-23T01:00:00+00:00',
#  'runtime': 74,
#  'rating': {'average': 7.8},
#  'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_landscape/152/381118.jpg',
#   'original': 'https://static.tvmaze.com/uploads/images/original_untouched/152/381118.jpg'},
#  'summary': '<p>In the aftermath of the host rebellion, the rescue team finds Bernard and the new Head of Operations asks for his help. Meanwhile, Delores promises to show Teddy the truth, and Maeve convinces Lee and Hector to help her find her daughter.</p>',
#  '_links': {'self': {'href': 'https://api.tvmaze.com/episodes/1214222'},
#   'show': {'href': 'https://api.tvmaze.com/shows/1371'}}}

# %%
for rating_data in rating_access:
    print(rating_access)
# Out:
# {'id': 1214222, 'url': 'https://www.tvmaze.com/episodes/1214222/westworld-2x01-journey-into-night', 'name': 'Journey Into Night', 'season': 2, 'number': 1, 'type': 'regular', 'airdate': '2018-04-22', 'airtime': '21:00', 'airstamp': '2018-04-23T01:00:00+00:00', 'runtime': 74, 'rating': {'average': 7.8}, 'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_landscape/152/381118.jpg', 'original': 'https://static.tvmaze.com/uploads/images/original_untouched/152/381118.jpg'}, 'summary': '<p>In the aftermath of the host rebellion, the rescue team finds Bernard and the new Head of Operations asks for his help. Meanwhile, Delores promises to show Teddy the truth, and Maeve convinces Lee and Hector to help her find her daughter.</p>', '_links': {'self': {'href': 'https://api.tvmaze.com/episodes/1214222'}, 'show': {'href': 'https://api.tvmaze.com/shows/1371'}}}
# ...

# %%
def get_rating():
    df1 = df["_embedded"]
    df2 = df1["episodes"]
    for data in df2:
        rating_access = df2[:]
# Out:
#   Input In [85]
#     print(data)
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# **Query - 2: Get all the episode names, whose average rating is more than 8 for every season**

# %%
temp = "rating"

# %%
res = [sub[temp] for sub in df2 if temp in sub.keys()]
# printing result
print("The extracted values : " + str(res))
# Out:
# The extracted values : [{'average': 8}, {'average': 7.7}, {'average': 7.6}, {'average': 7.9}, {'average': 8}, {'average': 8}, {'average': 8.6}, {'average': 7.9}, {'average': 8.5}, {'average': 8.7}, {'average': 7.8}, {'average': 7.7}, {'average': 7.7}, {'average': 8}, {'average': 7.6}, {'average': 7.7}, {'average': 7.9}, {'average': 8.7}, {'average': 8.4}, {'average': 8.5}, {'average': 8}, {'average': 7.8}, {'average': 7.8}, {'average': 8}, {'average': 7.9}, {'average': 7.5}, {'average': 7.5}, {'average': 7.7}, {'average': 7.1}, {'average': 7.4}, {'average': 7.6}, {'average': 7.7}, {'average': 7.8}, {'average': 7.5}, {'average': 7.7}, {'average': 7.5}]

# %% [markdown]
# **Query - 3: Get all the episode names that aired before May 2019**

# %%
df2
# Out:
# [{'id': 869671,
#   'url': 'https://www.tvmaze.com/episodes/869671/westworld-1x01-the-original',
#   'name': 'The Original',
#   'season': 1,
#   'number': 1,
#   'type': 'regular',
#   'airdate': '2016-10-02',
#   'airtime': '21:00',
#   'airstamp': '2016-10-03T01:00:00+00:00',
#   'runtime': 68,
#   'rating': {'average': 8},
#   'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_landscape/78/195475.jpg',
#    'original': 'https://static.tvmaze.com/uploads/images/original_untouched/78/195475.jpg'},
#   'summary': "<p>A woman named Dolores is a free spirit in the Old West... and unaware that she's actually an android, programmed to entertain rich guests seeking to act out their fantasies in an idealized vision of the 1880s. However, the people in charge soon realize that their androids are acting in ways that they didn't anticipate.</p>",
#   '_links': {'self': {'href': 'https://api.tvmaze.com/episodes/869671'},
# ...

# %%
len(df2[0:])
# Out:
# 36

# %%
temp = "airdate"
res = [sub[temp] for sub in df2 if temp in sub.keys()]
# printing result
print("The extracted values : " + str(res))
# Out:
# The extracted values : ['2016-10-02', '2016-10-09', '2016-10-16', '2016-10-23', '2016-10-30', '2016-11-06', '2016-11-13', '2016-11-20', '2016-11-27', '2016-12-04', '2018-04-22', '2018-04-29', '2018-05-06', '2018-05-13', '2018-05-20', '2018-05-27', '2018-06-03', '2018-06-10', '2018-06-17', '2018-06-24', '2020-03-15', '2020-03-22', '2020-03-29', '2020-04-05', '2020-04-12', '2020-04-19', '2020-04-26', '2020-05-03', '2022-06-26', '2022-07-03', '2022-07-10', '2022-07-17', '2022-07-24', '2022-07-31', '2022-08-07', '2022-08-14']

# %%
res
# Out:
# ['2016-10-02',
#  '2016-10-09',
#  '2016-10-16',
#  '2016-10-23',
#  '2016-10-30',
#  '2016-11-06',
#  '2016-11-13',
#  '2016-11-20',
#  '2016-11-27',
#  '2016-12-04',
#  '2018-04-22',
#  '2018-04-29',
#  '2018-05-06',
#  '2018-05-13',
#  '2018-05-20',
#  '2018-05-27',
#  '2018-06-03',
#  '2018-06-10',
#  '2018-06-17',
#  '2018-06-24',
#  '2020-03-15',
#  '2020-03-22',
#  '2020-03-29',
#  '2020-04-05',
#  '2020-04-12',
#  '2020-04-19',
#  '2020-04-26',
#  '2020-05-03',
#  '2022-06-26',
#  '2022-07-03',
#  '2022-07-10',
#  '2022-07-17',
#  '2022-07-24',
#  '2022-07-31',
#  '2022-08-07',
#  '2022-08-14']

# %% [markdown]
# **Get the summary for the most popular ( ratings ) episode in every season**

# %%
temp = "summary"
res = [sub[temp] for sub in df2 if temp in sub.keys()]
# printing result
print("The extracted values : " + str(res))
# Out:
# The extracted values : ["<p>A woman named Dolores is a free spirit in the Old West... and unaware that she's actually an android, programmed to entertain rich guests seeking to act out their fantasies in an idealized vision of the 1880s. However, the people in charge soon realize that their androids are acting in ways that they didn't anticipate.</p>", '<p>Bernard suspects that someone is sabotaging the hosts. Meanwhile, the Man continues his search for the deeper game, and Maeve finds herself in a world of hurt... literally.</p>', "<p>Bernard continues to investigate Dolores' supposed malfunction, and realizes that he has something unexpected on his hands. Meanwhile, Robert talks about the early days of the park, and Teddy receives a new role and narrative.</p>", '<p>While Dolores joins William and Logan on their adventure, the Man in Black continues his search for the entrance to the Maze and meets Armistice. Meanwhile, Robert reveals some of his true power to Theresa and advises h
# ...
